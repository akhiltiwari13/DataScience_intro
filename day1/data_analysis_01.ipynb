# %%
import os
os.getcwd()
# Out:
# '/home/akhil/files/learning/DataScience_intro/day1'

# %%
import pandas as pd
data_frame = pd.read_csv("../data_files/titanic.csv")

# %%
#This returns a random sample data from the entire data-frame.
data_frame.sample(5)
# Out:
#      PassengerId  Survived  Pclass                              Name  Gender  \
# 341          342         1       1    Fortune, Miss. Alice Elizabeth  female
# 483          484         1       3            Turkula, Mrs. (Hedwig)  female
# 421          422         0       3               Charters, Mr. David    male
# 572          573         1       1  Flynn, Mr. John Irwin ("Irving")    male
# 287          288         0       3              Naidenoff, Mr. Penko    male
#
#       Age  SibSp  Parch      Ticket      Fare        Cabin Embarked
# 341  24.0      3      2       19950  263.0000  C23 C25 C27        S
# 483  63.0      0      0        4134    9.5875          NaN        S
# 421  21.0      0      0  A/5. 13032    7.7333          NaN        Q
# 572  36.0      0      0    PC 17474   26.3875          E25        S
# 287  22.0      0      0      349206    7.8958          NaN        S

# %%
data_frame.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#      Gender   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data_frame.head() #default = 5
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data_frame.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data_frame.shape
# Out:
# (891, 12)

# %%
# exploratory data analysis (EDA) begins.

# %%
data_frame.index #displays current indexing logic for the data-frame.
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
data_frame # displays head + tail
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data_frame[  ['Name',	'Gender',	'Age']  ]
# Out:
#                                                   Name  Gender   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %%
data_frame.loc[[0, 85, 890]]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 85            86         1       3
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 85   Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  female  33.0      3
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Ticket   Fare Cabin Embarked
# 0        0  A/5 21171   7.25   NaN        S
# 85       0    3101278  15.85   NaN        S
# 890      0     370376   7.75   NaN        Q

# %%
data_frame.loc[[0,10,23,15]] [['Name',	'Gender',	'Age']] #CHAINING commands (it is an expensive operation)
# Out:
#                                 Name  Gender   Age
# 0            Braund, Mr. Owen Harris    male  22.0
# 10   Sandstrom, Miss. Marguerite Rut  female   4.0
# 23      Sloper, Mr. William Thompson    male  28.0
# 15  Hewlett, Mrs. (Mary D Kingcome)   female  55.0

# %%
data_frame.loc[[0,10,23,15]] [['Name',	'Gender',	'Age']].head()
# Out:
#                                 Name  Gender   Age
# 0            Braund, Mr. Owen Harris    male  22.0
# 10   Sandstrom, Miss. Marguerite Rut  female   4.0
# 23      Sloper, Mr. William Thompson    male  28.0
# 15  Hewlett, Mrs. (Mary D Kingcome)   female  55.0

# %%
data_frame[['Name', 'Gender']].loc[[20,23]]
# Out:
#                             Name Gender
# 20          Fynney, Mr. Joseph J   male
# 23  Sloper, Mr. William Thompson   male

# %%
#important, for conditional analysis of the data.
condition = data_frame ['Age']>25
# type(data_frame[condition])
# type(condition)
# data_frame.loc[condition]
data_frame[condition]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
con= data_frame['Age']
type(con)
# Out:
# pandas.core.series.Series

# %%
condition = data_frame ['Age'].between(20,30) #range
data_frame[condition]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 8              9         1       3
# 12            13         0       3
# 23            24         1       1
# ..           ...       ...     ...
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 889          890         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
condition = (data_frame ['Age'] < 30) & (data_frame ['Gender']== 'male')
# condition = ()&() put params between different conditions.
data_frame[condition][['Age', 'Name']]
# Out:
#       Age                            Name
# 0    22.0         Braund, Mr. Owen Harris
# 7     2.0  Palsson, Master. Gosta Leonard
# 12   20.0  Saundercock, Mr. William Henry
# 16    2.0            Rice, Master. Eugene
# 23   28.0    Sloper, Mr. William Thompson
# ..    ...                             ...
# 877  19.0            Petroff, Mr. Nedelio
# 883  28.0   Banfield, Mr. Frederick James
# 884  25.0          Sutehall, Mr. Henry Jr
# 886  27.0           Montvila, Rev. Juozas
# 889  26.0           Behr, Mr. Karl Howell
#
# [237 rows x 2 columns]

# %%
condition = (data_frame ['Age'] < 30) & (data_frame ['Gender']== 'male')
# condition = ()&() put params between different conditions.
data_frame[~condition][['Age', 'Name']]
# Out:
#       Age                                               Name
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    26.0                             Heikkinen, Miss. Laina
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    35.0                           Allen, Mr. William Henry
# 5     NaN                                   Moran, Mr. James
# ..    ...                                                ...
# 882  22.0                       Dahlberg, Miss. Gerda Ulrika
# 885  39.0               Rice, Mrs. William (Margaret Norton)
# 887  19.0                       Graham, Miss. Margaret Edith
# 888   NaN           Johnston, Miss. Catherine Helen "Carrie"
# 890  32.0                                Dooley, Mr. Patrick
#
# [654 rows x 2 columns]

# %%
condition = data_frame['Age'] < 30
data_frame[~condition][['Name','Age']]
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# 5                                     Moran, Mr. James   NaN
# 6                              McCarthy, Mr. Timothy J  54.0
# ..                                                 ...   ...
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 881                                 Markun, Mr. Johann  33.0
# 885               Rice, Mrs. William (Margaret Norton)  39.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 890                                Dooley, Mr. Patrick  32.0
#
# [507 rows x 2 columns]

# %%
data_frame.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import statistics

l = [11, 23, 34, 56, 34, 67, 33] #is a list, similar to a series?
# print(type(l))
statistics.quantiles(l, n=4, method = 'inclusive')
# Out:
# [28.0, 34.0, 45.0]

# %%
data_frame[['Age']].describe()
# Out:
#               Age
# count  714.000000
# mean    29.699118
# std     14.526497
# min      0.420000
# 25%     20.125000
# 50%     28.000000
# 75%     38.000000
# max     80.000000

# %%
data_frame[['Age', 'Fare']].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
def percent90(x):
    return 0.9*x

data_frame[['Age']].apply(percent90)
# data_frame[['Age']]
# Out:
#       Age
# 0    19.8
# 1    34.2
# 2    23.4
# 3    31.5
# 4    31.5
# ..    ...
# 886  24.3
# 887  17.1
# 888   NaN
# 889  23.4
# 890  28.8
#
# [891 rows x 1 columns]

# %%
# name & age of females pass from pclass 1 who are 30 or above in age

# %%
condition = (data_frame['Gender'] == 'female') & (data_frame['Age'] > 30) & (data_frame['Pclass'] == 1)
data_frame[condition][['Name', 'Age']]
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 11                            Bonnell, Miss. Elizabeth  58.0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  49.0
# 61                                 Icard, Miss. Amelie  38.0
# 177                         Isham, Miss. Ann Elizabeth  50.0
# 194          Brown, Mrs. James Joseph (Margaret Tobin)  44.0
# 195                               Lurette, Miss. Elise  58.0
# 215                            Newell, Miss. Madeleine  31.0
# 218                              Bazzani, Miss. Albina  32.0
# 230       Harris, Mrs. Henry Birkhardt (Irene Wallach)  35.0
# 258                                   Ward, Miss. Anna  35.0
# 268      Graham, Mrs. William Thompson (Edith Junkins)  58.0
# 269                             Bissette, Miss. Amelia  35.0
# ...

# %%
condition =  (data_frame['Pclass'] == 2) & (data_frame['Embarked'] == 'S')
data_frame[condition][['Fare']].mean()
# Out:
# Fare    20.327439
# dtype: float64

# %%
condition =  (data_frame['Fare'] > 500) & (data_frame['Pclass'] == 2)
data_frame[condition].head()
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Gender, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df= pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df.sample(len(df[['PassengerId']]))
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 550          551         1       1               Thayer, Mr. John Borland Jr
# 424          425         0       3               Rosblom, Mr. Viktor Richard
# 62            63         0       1               Harris, Mr. Henry Birkhardt
# 460          461         1       1                       Anderson, Mr. Harry
# 157          158         0       3                           Corn, Mr. Harry
# ..           ...       ...     ...                                       ...
# 68            69         1       3           Andersson, Miss. Erna Alexandra
# 479          480         1       3                  Hirvonen, Miss. Hildur E
# 737          738         1       1                    Lesurer, Mr. Gustave J
# 137          138         0       1               Futrelle, Mr. Jacques Heath
# 699          700         0       3  Humblen, Mr. Adolf Mathias Nicolai Olsen
#
# ...

# %%
dfxls = pd.read_excel('../data_files/Data_excel.xls')
dfxls.sample()
# Out:
#          STA       Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp  \
# 41958  13601 1944-03-29      0          NaN  18.888889  15.555556  17.222222
#
#        Snowfall PoorWeather  YR  ...  FB  FTI ITH  PGT  TSHDSBRSGF  SD3  RHX  \
# 41958       0.0         NaN  44  ... NaN  NaN NaN  NaN         NaN  NaN  NaN
#
#        RHN RVG  WTE
# 41958  NaN NaN  NaN
#
# [1 rows x 31 columns]

# %%
temp = dfxls.groupby(['Gender'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-3a2eceb2ae87> in <module>
# ----> 1 temp = dfxls.groupby(['Gender'])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# ...

# %%
len(data_frame['PassengerId'])
# Out:
# 891

# %%
data_frame['Gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
tmp = data_frame.groupby(['Gender'])
tmp.get_group('female')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
tmp = data_frame.groupby(['Gender', 'Pclass'])
tmp.get_group(('female',3))
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 14            15         0       3
# 18            19         0       3
# ..           ...       ...     ...
# 863          864         0       3
# 875          876         1       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2 = pd.read_excel('../data_files/TitanicSheets.xlsx', sheet_name='P1')
df2
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             1            2         1       1
# 1             3            4         1       1
# 2             6            7         0       1
# 3            11           12         1       1
# 4            23           24         1       1
# ..          ...          ...       ...     ...
# 211         871          872         1       1
# 212         872          873         0       1
# 213         879          880         1       1
# 214         887          888         1       1
# 215         889          890         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                             Bonnell, Miss. Elizabeth  female  58.0      0
# ...

# %%
df2.drop(['Unnamed: 0'], axis=1, inplace=True)
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2              7         0       1
# 3             12         1       1
# 4             24         1       1
# ..           ...       ...     ...
# 211          872         1       1
# 212          873         0       1
# 213          880         1       1
# 214          888         1       1
# 215          890         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                             Bonnell, Miss. Elizabeth  female  58.0      0
# 4                         Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.drop([211], axis=0, inplace=True)
df2
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             1            2         1       1
# 1             3            4         1       1
# 2             6            7         0       1
# 3            11           12         1       1
# 4            23           24         1       1
# ..          ...          ...       ...     ...
# 210         867          868         0       1
# 212         872          873         0       1
# 213         879          880         1       1
# 214         887          888         1       1
# 215         889          890         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                             Bonnell, Miss. Elizabeth  female  58.0      0
# ...

# %%
df2.sort_values(by=['Name', 'Age'], ascending=[False, True])
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 72          325          326         1       1
# 132         555          556         0       1
# 12           55           56         1       1
# 81          351          352         0       1
# 29          155          156         0       1
# ..          ...          ...       ...     ...
# 105         460          461         1       1
# 115         498          499         0       1
# 61          297          298         0       1
# 64          305          306         1       1
# 178         730          731         1       1
#
#                                                 Name  Gender    Age  SibSp  \
# 72                          Young, Miss. Marie Grice  female  36.00      0
# 132                               Wright, Mr. George    male  62.00      0
# 12                                 Woolner, Mr. Hugh    male    NaN      0
# 81            Williams-Lambert, Mr. Fletcher Fellows    male    NaN      0
# ...

# %%
df2.loc[[81], ['Name', 'Gender']] #this is faster than chaining commands.
# Out:
#                                       Name Gender
# 81  Williams-Lambert, Mr. Fletcher Fellows   male

# %%
type(df2.loc[[81],['Name','Gender']])  #this is faster than chaining commands.
# Out:
# pandas.core.frame.DataFrame

# %%
def constfunct(x):
    return "constfuct"

df2['NewCol']= df2['Name'].apply(constfunct)
df2[['NewCol']]
# Out:
#         NewCol
# 0    constfuct
# 1    constfuct
# 2    constfuct
# 3    constfuct
# 4    constfuct
# ..         ...
# 210  constfuct
# 212  constfuct
# 213  constfuct
# 214  constfuct
# 215  constfuct
#
# [215 rows x 1 columns]

# %%
# col1
col1 = df2[['Gender']]
col1
# Out:
#      Gender
# 0    female
# 1    female
# 2      male
# 3    female
# 4      male
# ..      ...
# 210    male
# 212    male
# 213  female
# 214  female
# 215    male
#
# [215 rows x 1 columns]

# %%
df2.loc[[210,215],['Gender']]
# Out:
#     Gender
# 210   male
# 215   male

# %%
data_frame.to_csv('titanic_write.csv', columns= ['Name'], index=False)

# %%
data_frame.to_excel('analysis_write.xlsx', index=False)

# %%
writer = pd.ExcelWriter('analysisExcel_write.xlsx')
data_frame.to_excel(writer, index=False, sheet_name= 'SHEET1')
data_frame.to_excel(writer, index=False, sheet_name= 'SHEET2')

writer.save()
