# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.set_context('notebook')
sns.set_style('dark')
sns.scatterplot(x='Age', y='Fare',hue='Survived', data=df )

# %%
sns.countplot(df['Gender'], hue=df['Survived'])

# %%
sns.boxplot(x=df['Gender'], y=df['Age'],hue=df['Pclass'])

# %%
sns.lineplot(x=df['Age'], y=df['Fare'])

# %%
sns.swarmplot(x=df['Gender'], y=df['Fare'], hue=df['Pclass'], palette='autumn')

# %%
sns.pairplot(data=df)

# %%
sns.heatmap(df[['Fare']])

# %%
sns.distplot(df[['Age']],kde=False)

# %%
import numpy as np
binnew = np.linspace(0,100)
sns.distplot(df[['Age']],kde=False, bins=binnew)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
grid = sns.FacetGrid(df, row='Gender', col='Pclass', margin_titles=True)
grid.map(plt.hist, 'Age', bins=np.linspace(0,100,10))

# %%
grid = sns.FacetGrid(df, row='Gender', col='Survived', margin_titles=True)
grid.map(plt.hist, 'Age', bins=np.linspace(0,100,10))

# %%
grid = sns.FacetGrid(df, row='Gender', col='Survived', margin_titles=True)
grid.map(sns.scatterplot, 'Age','Fare')

# %%
temp =df.groupby('Embarked')
temp.groups
# sns.countplot(x=df['Embarked'], y=df['Survivied'],hue=df['Fare'], data=df )
# Out:
# {'C': Int64Index([  1,   9,  19,  26,  30,  31,  34,  36,  39,  42,
#              ...
#              847, 849, 852, 858, 859, 866, 874, 875, 879, 889],
#             dtype='int64', length=168),
#  'Q': Int64Index([  5,  16,  22,  28,  32,  44,  46,  47,  82, 109, 116, 126, 143,
#              156, 171, 186, 188, 196, 198, 208, 214, 241, 245, 260, 264, 274,
#              278, 280, 289, 300, 301, 303, 322, 330, 358, 359, 364, 368, 388,
#              411, 412, 421, 428, 459, 468, 501, 502, 510, 517, 525, 552, 560,
#              573, 593, 612, 613, 626, 629, 653, 654, 657, 680, 697, 703, 718,
#              727, 749, 767, 768, 776, 778, 787, 790, 825, 828, 885, 890],
#             dtype='int64'),
#  'S': Int64Index([  0,   2,   3,   4,   6,   7,   8,  10,  11,  12,
#              ...
#              877, 878, 880, 881, 882, 883, 884, 886, 887, 888],
#             dtype='int64', length=644)}

# %%
df1=temp.get_group('C')[['Survived', 'Pclass']]
df2=temp.get_group('S')[['Survived', 'Pclass']]
# df3=temp.get_group('C')[['Survived', 'Pclass']]

sns.countplot(df1['Survived'],hue=df1['Pclass'])
# sns.countplot(temp.get_group('S')[['Survived', 'Pclass']])

# %%
sns.countplot(df2['Survived'],hue=df2['Pclass'])

# %%
#what's this?
grid = sns.FacetGrid(df, row='Gender', col='Survived', margin_titles=True)
grid.map(sns.countplot, 'Age')

# %%
sns.catplot(x='Survived', hue='Pclass', col='Embarked', data=df, kind = "count", palette='inferno')

# %%
g=sns.countplot(df['Gender'])

plt.xlabel('Gender of Passenger')
plt.ylabel('Count of Passenger')
plt.yticks([0,500,1000])
plt.title('Gender Count')

plt.rc('font',size=12)
plt.rc('axes',titlesize=40)
plt.rc('ytick',labelsize=30)

plt.show(g)
type(g)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
g=sns.distplot(df['Age'])

plt.xlabel('Age of Passenger')
plt.ylabel('Densitiy')
plt.xticks([x for x in range(0,80,10)])
plt.title('Distplot')

plt.show(g)
type(g)
# Out:
# matplotlib.axes._subplots.AxesSubplot
