# %%
# !pip install --upgrade snowflake-sqlalchemy
# !pip install --upgrade pandas
# !pip install --upgrade faker

# %%
# connect to mariaDB to read the dummy data.
# from sqlalchemy import create_engine

# engine = create_engine("mysql+pymysql://root:Redhat@10.250.34.214:7001/rms28?charset=utf8mb4")
# engine.connect()
# print(engine)

# %%
from sqlalchemy.types import Integer, Text, String, DateTime

# script to create a dataframe of random mock data.
import pandas
from faker import Factory
import random
from datetime import datetime
from datetime import date

faker = Factory.create()
status = 'created,delivered,returned'.split(',')

def date_between(d1, d2):
    f = '%b%d-%Y'
    return faker.date_time_between_dates(datetime.strptime(d1, f), datetime.strptime(d2, f))


def mockPCAPRecord():
    return {'id': faker.numerify('###'),  # random number eg:235533
            'posting_date': date_between('may19-2019', 'jan01-2021'),
            '50_prcntile_fwd_new': faker.numerify('##'),  # top n (n-percentile) order's latency numbers in seconds (randomly gen.) 
            '50_prcntile_fwd_cxl': faker.numerify('##'),
            '50_prcntile_fwd_mod': faker.numerify('##'),
            '50_prcntile_rev_new': faker.numerify('##'),
            '50_prcntile_rev_cxl': faker.numerify('##'),
            '50_prcntile_rev_mod': faker.numerify('##'),
            "90_prcntile_fwd_new": faker.numerify('##'),
            "90_prcntile_fwd_cxl": faker.numerify('##'),
            "90_prcntile_fwd_mod": faker.numerify('##'),
            "90_prcntile_rev_new": faker.numerify('##'),
            "90_prcntile_rev_cxl": faker.numerify('##'),
            "90_prcntile_rev_mod": faker.numerify('##'),
            "99_prcntile_fwd_new": faker.numerify('##'),
            "99_prcntile_fwd_cxl": faker.numerify('##'),
            "99_prcntile_fwd_mod": faker.numerify('##'),
            "99_prcntile_rev_new": faker.numerify('##'),
            "99_prcntile_rev_cxl": faker.numerify('##'),
            "99_prcntile_rev_mod": faker.numerify('##'),
            "avg_fwd_new": faker.numerify('##'),
            "avgfwd_cxl": faker.numerify('##'),
            "avg_fwd_mod": faker.numerify('##'),
            "avg_rev_new": faker.numerify('##'),
            "avg_rev_cxl": faker.numerify('##'),
            "avg_rev_mod": faker.numerify('##'),
            "posting_updated": date.today()        
             }

example_dummy_data = pandas.DataFrame([mockPCAPRecord() for _ in range(1000)])
example_dummy_data.sample(5)

# table_name = 'pcapMockData'

# example_dummy_data.to_sql(
#     table_name,
#     engine,
#     if_exists='replace',
#     index=False,
#     chunksize=500,
#     dtype={
#         "id": Integer,
#         "posting_date": DateTime,
#         "50_prcntile_fwd_new": Integer,
#         "50_prcntile_fwd_cxl": Integer,
#         "50_prcntile_fwd_mod": Integer,
#         "50_prcntile_rev_new": Integer,
#         "50_prcntile_rev_cxl": Integer,
#         "50_prcntile_rev_mod": Integer,
#         "90_prcntile_fwd_new": Integer,
#         "90_prcntile_fwd_cxl": Integer,
#         "90_prcntile_fwd_mod": Integer,
#         "90_prcntile_rev_new": Integer,
#         "90_prcntile_rev_cxl": Integer,
#         "90_prcntile_rev_mod": Integer,
#         "99_prcntile_fwd_new": Integer,
#         "99_prcntile_fwd_cxl": Integer,
#         "99_prcntile_fwd_mod": Integer,
#         "99_prcntile_rev_new": Integer,
#         "99_prcntile_rev_cxl": Integer,
#         "99_prcntile_rev_mod": Integer,
#         "avg_fwd_new": Integer,
#         "avgfwd_cxl": Integer,
#         "avg_fwd_mod": Integer,
#         "avg_rev_new": Integer,
#         "avg_rev_cxl": Integer,
#         "avg_rev_mod": Integer,
#         "posting_updated": DateTime
#     }
# )
# Out:
#       id        posting_date 50_prcntile_fwd_new 50_prcntile_fwd_cxl  \
# 400  287 2019-12-12 20:21:55                  69                  06
# 687  809 2020-04-18 01:01:06                  70                  14
# 486  111 2020-07-21 01:13:52                  84                  01
# 319  161 2020-12-26 16:21:29                  16                  13
# 960  363 2020-07-12 06:25:46                  00                  78
#
#     50_prcntile_fwd_mod 50_prcntile_rev_new 50_prcntile_rev_cxl  \
# 400                  27                  89                  81
# 687                  00                  60                  52
# 486                  57                  66                  76
# 319                  49                  29                  02
# 960                  16                  60                  22
#
#     50_prcntile_rev_mod 90_prcntile_fwd_new 90_prcntile_fwd_cxl  ...  \
# 400                  16                  34                  95  ...
# 687                  57                  59                  81  ...
# 486                  96                  79                  18  ...
# 319                  93                  61                  96  ...
# 960                  47                  52                  97  ...
#
#     99_prcntile_rev_new 99_prcntile_rev_cxl 99_prcntile_rev_mod avg_fwd_new  \
# 400                  34                  53                  18          87
# 687                  11                  13                  39          28
# 486                  63                  43                  79          59
# 319                  75                  65                  41          08
# 960                  36                  24                  71          30
#
#     avgfwd_cxl avg_fwd_mod avg_rev_new avg_rev_cxl avg_rev_mod posting_updated
# 400         78          69          59          17          87      2021-02-02
# 687         95          33          97          60          17      2021-02-02
# 486         93          53          54          63          59      2021-02-02
# 319         44          88          39          55          13      2021-02-02
# 960         44          26          84          99          71      2021-02-02
#
# [5 rows x 27 columns]

# %%
# read data from tables
# with engine.connect() as conn, conn.begin():
#     data = pandas.read_sql_table("pcapMockData", conn)

# begin work on data-frame.
# data.sample(10)
